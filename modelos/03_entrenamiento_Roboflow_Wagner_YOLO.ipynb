# %% [markdown]
# # ⚡ PISTA 3: Detección Rápida en Tiempo Real & Wagner 0-5 (YOLOv8)
# ### Dataset: Roboflow DFU Universe (3.500+ fotos anotadas)
# **piediabetico.lat — Pre-filtro y Clasificación Rápida**
#
# Este cuaderno entrena **YOLOv8** para:
# 1. Detectar el pie y encuadrar automáticamente la úlcera en tiempo real.
# 2. Clasificar el grado de severidad según la escala **Wagner (0 a 5)**.
# 3. Exportar a **`dfu_yolov8_wagner.onnx`** (ultraliviano para teléfonos y web).

# %%
# ── 1. INSTALACIÓN DE ULTRALYTICS Y ONNX ────────────────────────────────
# !pip install -q ultralytics onnx onnxruntime albumentations opencv-python
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 88.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 79.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 2.7 MB/s eta 0:00:00

# %%
# ── 2. DESCARGA DEL DATASET DE ROBOFLOW (DFU UNIVERSE) ─────────────────
import os
# !mkdir -p /content/dataset_yolo
print('Listo para vincular dataset de Roboflow DFU Universe en formato YOLOv8.')
# Se puede usar curl o la API de Roboflow para descargar en 1 línea
# Out:
# Listo para vincular dataset de Roboflow DFU Universe en formato YOLOv8.

# %%
# ── 3. ENTRENAMIENTO DE YOLOV8-NANO (ULTRALIVIANO) ─────────────────────
from ultralytics import YOLO

# Cargamos el modelo pre-entrenado nano (el más rápido)
model = YOLO('yolov8n.pt')

print('Iniciando configuración de entrenamiento para detección de úlceras...')
# model.train(data='dfu_data.yaml', epochs=30, imgsz=640, batch=16, device=0)
# Out:
# Creating new Ultralytics Settings v0.0.7 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.
# ...
# Iniciando configuración de entrenamiento para detección de úlceras...

# %%
# ── 4. EXPORTACIÓN AUTOMÁTICA EN 1 LÍNEA A FORMATO ONNX ────────────────
# Al terminar el entrenamiento, Ultralytics exporta nativamente a ONNX:
# model.export(format='onnx', dynamic=True, opset=14)
print('Comando de exportación: model.export(format="onnx") listo.')
# Out:
# Comando de exportación: model.export(format="onnx") listo.
